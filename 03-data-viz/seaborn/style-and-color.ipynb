# %% [markdown]
# # Style and Color
#
# How to control figure aesthetics in seaborn ?

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips = sns.load_dataset('tips')

# %% [markdown]
# ## Styles
#
# You can set particular styles:

# %%
sns.countplot(x='sex',data=tips)
plt.show()

# %%
sns.set_style('white')
sns.countplot(x='sex',data=tips)
plt.show()

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=tips,palette='deep')
plt.show()
# Out:
# /tmp/ipykernel_46951/2811225396.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='deep')

# %% [markdown]
# ## Spine Removal

# %%
sns.countplot(x='sex',data=tips)
sns.despine()
plt.show()

# %%
sns.countplot(x='sex',data=tips)
sns.despine(left=True)
plt.show()

# %% [markdown]
# ## Size and Aspect

# %% [markdown]
# You can use matplotlib's **plt.figure(figsize=(width,height) ** to change the size of most seaborn plots.
#
# You can control the size and aspect ratio of most seaborn grid plots by passing in parameters: size, and aspect. For example:

# %%
# Non Grid Plot
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)
plt.show()

# %%
# Grid Type Plot
sns.lmplot(x='total_bill',y='tip',aspect=4,data=tips)
plt.show()

# %% [markdown]
# ## Scale and Context
#
# The set_context() allows you to override default parameters:

# %%
sns.set_context('poster',font_scale=4)
sns.countplot(x='sex',data=tips,palette='coolwarm', width=0.4)
plt.show()
# Out:
# /tmp/ipykernel_46951/2259914125.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='coolwarm', width=0.4)
