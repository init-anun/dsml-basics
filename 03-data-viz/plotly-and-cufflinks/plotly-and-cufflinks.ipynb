# %% [markdown]
# # Plotly and Cufflinks

# %% [markdown]
# Plotly is a library that allows you to create interactive plots that you can use in dashboards or websites (you can save them as html files or static images).

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 6.8.0

# %%
import cufflinks as cf

# %%
# For Notebooks
init_notebook_mode(connected=True)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.6.0.min"</script>

# %%
# For offline use
cf.go_offline()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.6.0.min"</script>

# %% [markdown]
# ### Fake Data

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -1.016176  0.406488  1.089398 -1.214799
# 1 -0.070926  0.800685 -0.741013  1.497894
# 2  0.958245 -1.538543  1.098858  0.207671
# 3 -0.654216 -0.810578 -1.321927  0.520664
# 4 -0.157600  1.341582  0.020438  1.294379

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df2.head()
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# ## Using Cufflinks and iplot()
#
# * scatter
# * bar
# * box
# * spread
# * ratio
# * heatmap
# * surface
# * histogram
# * bubble

# %% [markdown]
# ## Scatter

# %%
# df.iplot(kind='scatter',x='A',y='B',mode='markers',size=10)
# plt.show()

import plotly.express as px

# Create the interactive scatter plot and pass the marker size directly
fig = px.scatter(df, x="A", y="B", size_max=10)

# If you want ALL markers to be a fixed size of 10 explicitly:
fig.update_traces(marker=dict(size=10))

# Display the interactive Plotly graph
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Bar Plots

# %%
df2.iplot(kind='bar',x='Category',y='Values')

# %%
df.count().iplot(kind='bar')

# %% [markdown]
# ## Boxplots

# %%
df.iplot(kind='box')

# %% [markdown]
# ## 3d Surface

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})
df3.iplot(kind='surface',colorscale='rdylbu')

# %% [markdown]
# ## Spread

# %%
df[['A','B']].iplot(kind='spread')

# %% [markdown]
# ## histogram

# %%
df['A'].iplot(kind='hist',bins=25)

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')

# %% [markdown]
# ## scatter_matrix()
#
# Similar to sns.pairplot()

# %%
df.scatter_matrix()
