# %% [markdown]
# # Data Input and Output
#
# For getting input and output, pandas can read a variety of file types using its pd.read_ methods. Some of the most common data types:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
df = pd.read_csv('example')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# ### CSV Output

# %%
df.to_csv('example',index=False)

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %% [markdown]
# ### Excel Input

# %%
pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %% [markdown]
# ### Excel Output

# %%
df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %% [markdown]
# ## HTML
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %% [markdown]
# ### HTML Input
#
# Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df[0]
# Out:
#                                             Bank Name                City  \
# 0             Community Bank and Trust - West Georgia            LaGrange
# 1                   Metropolitan Capital Bank & Trust             Chicago
# 2                        The Santa Anna National Bank          Santa Anna
# 3                                Pulaski Savings Bank             Chicago
# 4                  The First National Bank of Lindsay             Lindsay
# 5               Republic First Bank dba Republic Bank        Philadelphia
# 6                                       Citizens Bank            Sac City
# 7                            Heartland Tri-State Bank             Elkhart
# 8                                 First Republic Bank       San Francisco
# 9                                      Signature Bank            New York
# 10                                Silicon Valley Bank         Santa Clara
# 11                                  Almena State Bank              Almena
# 12                         First City Bank of Florida   Fort Walton Beach
# 13                               The First State Bank       Barboursville
# 14                                 Ericson State Bank             Ericson
# 15                   City National Bank of New Jersey              Newark
# 16                                      Resolute Bank              Maumee
# 17                              Louisa Community Bank              Louisa
# 18                               The Enloe State Bank              Cooper
# 19                Washington Federal Bank for Savings             Chicago
# 20    The Farmers and Merchants State Bank of Argonia             Argonia
# 21                                Fayette County Bank          Saint Elmo
# 22  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 23                                     First NBC Bank         New Orleans
# 24                                      Proficio Bank  Cottonwood Heights
#
#             State   Cert                Acquiring Institution  \
# 0         Georgia  25796                          Anchor Bank
# 1        Illinois  57488              First Independence Bank
# 2           Texas   5520            Coleman County State Bank
# 3        Illinois  28611                      Millennium Bank
# 4        Oklahoma   4134               First Bank & Trust Co.
# 5    Pennsylvania  27332    Fulton Bank, National Association
# 6            Iowa   8758            Iowa Trust & Savings Bank
# 7          Kansas  25851               Dream First Bank, N.A.
# 8      California  59017            JPMorgan Chase Bank, N.A.
# 9        New York  57053                  Flagstar Bank, N.A.
# 10     California  24735  First–Citizens Bank & Trust Company
# 11         Kansas  15426                          Equity Bank
# 12        Florida  16748            United Fidelity Bank, fsb
# 13  West Virginia  14361                       MVB Bank, Inc.
# 14       Nebraska  18265           Farmers and Merchants Bank
# 15     New Jersey  21111                      Industrial Bank
# 16           Ohio  58317                   Buckeye State Bank
# 17       Kentucky  58112    Kentucky Farmers Bank Corporation
# 18          Texas  10716                   Legend Bank, N. A.
# 19       Illinois  30570                   Royal Savings Bank
# 20         Kansas  17719                          Conway Bank
# 21       Illinois   1802            United Fidelity Bank, fsb
# 22      Wisconsin  30003  First-Citizens Bank & Trust Company
# 23      Louisiana  58302                         Whitney Bank
# 24           Utah  35495                    Cache Valley Bank
#
#          Closing Date  Fund  Sort ascending
# 0         May 1, 2026                 10551
# 1    January 30, 2026                 10550
# 2       June 27, 2025                 10549
# 3    January 17, 2025                 10548
# 4    October 18, 2024                 10547
# 5      April 26, 2024                 10546
# 6    November 3, 2023                 10545
# 7       July 28, 2023                 10544
# 8         May 1, 2023                 10543
# 9      March 12, 2023                 10540
# 10     March 10, 2023                 10539
# 11   October 23, 2020                 10538
# 12   October 16, 2020                 10537
# 13      April 3, 2020                 10536
# 14  February 14, 2020                 10535
# 15   November 1, 2019                 10534
# 16   October 25, 2019                 10533
# 17   October 25, 2019                 10532
# 18       May 31, 2019                 10531
# 19  December 15, 2017                 10530
# 20   October 13, 2017                 10529
# 21       May 26, 2017                 10528
# 22        May 5, 2017                 10527
# 23     April 28, 2017                 10526
# 24      March 3, 2017                 10525

# %% [markdown]
# ____

# %% [markdown]
# _____
# _____
# # SQL

# %% [markdown]
# The pandas.io.sql module provides a collection of query wrappers to both facilitate data retrieval and to reduce dependency on DB-specific API. Database abstraction is provided by SQLAlchemy if installed. In addition you will need a driver library for your database. Examples of such drivers are psycopg2 for PostgreSQL or pymysql for MySQL. For SQLite this is included in Python’s standard library by default. You can find an overview of supported drivers for each SQL dialect in the SQLAlchemy docs.
#
#
# If SQLAlchemy is not installed, a fallback is only provided for sqlite (and for mysql for backwards compatibility, but this is deprecated and will be removed in a future version). This mode requires a Python database adapter which respect the Python DB-API.
#
# See also some cookbook examples for some advanced strategies.
#
# The key functions are:
#
# * read_sql_table(table_name, con[, schema, ...])
#     * Read SQL database table into a DataFrame.
# * read_sql_query(sql, con[, index_col, ...])
#     * Read SQL query into a DataFrame.
# * read_sql(sql, con[, index_col, ...])
#     * Read SQL query or database table into a DataFrame.
# * DataFrame.to_sql(name, con[, flavor, ...])
#     * Write records stored in a DataFrame to a SQL database.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
print(type(df))
# Out:
# <class 'list'>

# %%
df[0].to_sql('data', engine)
# Out:
# 25

# %%
sql_df = pd.read_sql('data',con=engine)

# %%
sql_df
# Out:
#     index                                          Bank Name  \
# 0       0            Community Bank and Trust - West Georgia
# 1       1                  Metropolitan Capital Bank & Trust
# 2       2                       The Santa Anna National Bank
# 3       3                               Pulaski Savings Bank
# 4       4                 The First National Bank of Lindsay
# 5       5              Republic First Bank dba Republic Bank
# 6       6                                      Citizens Bank
# 7       7                           Heartland Tri-State Bank
# 8       8                                First Republic Bank
# 9       9                                     Signature Bank
# 10     10                                Silicon Valley Bank
# 11     11                                  Almena State Bank
# 12     12                         First City Bank of Florida
# 13     13                               The First State Bank
# 14     14                                 Ericson State Bank
# 15     15                   City National Bank of New Jersey
# 16     16                                      Resolute Bank
# 17     17                              Louisa Community Bank
# 18     18                               The Enloe State Bank
# 19     19                Washington Federal Bank for Savings
# 20     20    The Farmers and Merchants State Bank of Argonia
# 21     21                                Fayette County Bank
# 22     22  Guaranty Bank, (d/b/a BestBank in Georgia & Mi