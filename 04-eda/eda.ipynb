# %%
# Import libraries

import pandas as pd
from sqlalchemy import create_engine
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# setup database connection (Mysql database)
db_user = 'root'
db_password = 'root'
db_host = 'localhost'
db_port = '3306'
db_name = 'school'

# create the connection engine
engine = create_engine(f'mysql+pymysql://{db_user}:{db_password}@{db_host}:{db_port}/{db_user}')

# %%
#
